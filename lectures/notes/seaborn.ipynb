# %% [markdown]
# ## Introduction to Seaborn

# %% [markdown]
# **Seaborn** is a powerful Python library for data visualization built on top of Matplotlib.
#
# While Matplotlib is great for creating basic plots, Seaborn makes it easier to create beautiful, informative visualizations with less effort.

# %% [markdown]
# Some commononly used Seaborn plots are:
#
# * Scatter plots
# * Line plots
# * Bar plots
# * Violin plots
# * Pair plots
# * Regression plots
# * Historgram plots

# %% [markdown]
# _____

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Built-in Seaborn datasets

# %%
tips_df = sns.load_dataset('tips')

tips_df

# %% [markdown]
# _____

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(data=tips_df, x='total_bill', y='tip')

# %% [markdown]
# We can add more dimensions of data!
#
# **Add categorical differentiation**

# %%
sns.scatterplot(data=tips_df, x='total_bill', y='tip', hue='sex')

# %% [markdown]
# ____

# %% [markdown]
# ## Line plots

# %%
flights_df = sns.load_dataset('flights')

flights_df.head(15)

# %%
sns.lineplot(data=flights_df, x='year', y='passengers')

# %% [markdown]
# **Grouping by category month**

# %%
sns.lineplot(data=flights_df, x='year', y='passengers', hue='month')
plt.show()

# %% [markdown]
# _____

# %% [markdown]
# ## Bar plots

# %%
tips_df

# %%
sns.barplot(data=tips_df, x='day', y='total_bill')
#plt.ylim(17)  # dont do this pls.
plt.show()

# %%
sns.barplot(data=tips_df, x='day', y='total_bill', hue='sex')
plt.show()

# %% [markdown]
# _____
#
# ## Violin plots

# %%
sns.violinplot(data=tips_df, x='day', y='total_bill')
plt.show()

# %%
sns.violinplot(data=tips_df, x='day', y='total_bill', hue='smoker')
plt.show()

# %% [markdown]
# ______

# %% [markdown]
# ## Histogram

# %%
sns.histplot(data=tips_df, x='total_bill', bins=30)
plt.show()

# %%
sns.histplot(data=tips_df, x='total_bill', bins=30, hue='smoker', kde=True)
plt.show()

# %% [markdown]
# ____
#
# ## Pair plots

# %%
sns.pairplot(data=tips_df)
plt.show()

# %% [markdown]
# ____
#
# ## KDE Plot

# %%
sns.kdeplot(data=tips_df, x='total_bill', hue='smoker')
plt.show()

# %% [markdown]
# _____
#
# ## Settings themes

# %%
sns.set_theme(style='whitegrid') # there are MANY different themes available, look them up in the documentation/online

sns.scatterplot(data=tips_df, x='total_bill', y='tip', hue='sex')
plt.show()

# %% [markdown]
# _____
#
# ## Color Palettes

# %%
sns.set_palette('bright')  # there are MANY different palettes available, look them up in the documentation/online
 
sns.scatterplot(data=tips_df, x='total_bill', y='tip', hue='sex')
plt.show()

# %% [markdown]
# ____
#
# ## Combining with Matplotlib

# %%
sns.set_palette('pastel')

sns.scatterplot(x='total_bill', y='tip', data=tips_df, hue='sex')

plt.title('My title is here')
plt.xlabel('This was clear af')
plt.ylabel('woooo')
plt.show()
